# %%
# import bibliotek oraz funkcji

import pandas as pd
import sys
sys.path.append("../utils")
from cleaning  import clean_column_and_save
from load_data import load_data
from remove_nan_columns import remove_nan_columns
from red_flag_analyzer import red_flag_analyzer

# %%
df =load_data('../data/raw_data/history.csv')
clean_column_and_save(df)
# Out:
# Dane zapisane w:  ../data/clean_data/before_eda/cleaned_creditcard.csv
#     data_transakcji data_księgowania  dane_kontrahenta  \
# 0        2019-01-01       2019-01-03             Orlen
# 1        2019-01-01       2019-01-02  Biuro Notarialne
# 2        2019-01-04       2019-01-04        PokerStars
# 3        2019-01-06       2019-01-07            Amazon
# 4        2019-01-10       2019-01-11    Urząd Skarbowy
# ..              ...              ...               ...
# 995      2024-12-28       2024-12-30             Zabka
# 996      2024-12-29       2024-12-31  Biuro Notarialne
# 997      2024-12-29       2024-12-30         Firma XYZ
# 998      2024-12-30       2024-12-30             Orlen
# 999      2024-12-31       2025-01-01            STS.pl
#
#                          tytuł                   nr_rachunku nazwa_banku  \
# 0               Płatność Orlen  PL47525525636630696177023059       mBank
# 1    Płatność Biuro Notarialne  PL72634487227183186158541068         ING
# ...

# %%
df.head()
# Out:
#   data_transakcji data_księgowania  dane_kontrahenta  \
# 0      2019-01-01       2019-01-03             Orlen
# 1      2019-01-01       2019-01-02  Biuro Notarialne
# 2      2019-01-04       2019-01-04        PokerStars
# 3      2019-01-06       2019-01-07            Amazon
# 4      2019-01-10       2019-01-11    Urząd Skarbowy
#
#                        tytuł                   nr_rachunku nazwa_banku  \
# 0             Płatność Orlen  PL47525525636630696177023059       mBank
# 1  Płatność Biuro Notarialne  PL72634487227183186158541068         ING
# 2        Płatność PokerStars  PL85502768236074445829791826   Santander
# 3            Płatność Amazon  PL74448559599291860253081347       mBank
# 4    Płatność Urząd Skarbowy  PL99999005218950489518997577       mBank
#
#    szczegóły  nr_transakcji  kwota_transakcji_(waluta_rachunku) waluta  \
# 0        NaN     7979693581                             -227.33    PLN
# 1        NaN     9417345785                            -9887.59    PLN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   data_transakcji                     1000 non-null   object
#  1   data_księgowania                    1000 non-null   object
#  2   dane_kontrahenta                    1000 non-null   object
#  3   tytuł                               1000 non-null   object
#  4   nr_rachunku                         1000 non-null   object
#  5   nazwa_banku                         1000 non-null   object
#  6   szczegóły                           0 non-null      float64
#  7   nr_transakcji                       1000 non-null   int64
#  8   kwota_transakcji_(waluta_rachunku)  1000 non-null   float64
#  9   waluta                              1000 non-null   object
#  10  kwota_blokady/zwolnienie_blokady    0 non-null      float64
# ...

# %%
#Usunięcie kolumn, które nie posiadają wartości 

remove_nan_columns(df)
df
# Out:
#     data_transakcji data_księgowania  dane_kontrahenta  \
# 0        2019-01-01       2019-01-03             Orlen
# 1        2019-01-01       2019-01-02  Biuro Notarialne
# 2        2019-01-04       2019-01-04        PokerStars
# 3        2019-01-06       2019-01-07            Amazon
# 4        2019-01-10       2019-01-11    Urząd Skarbowy
# ..              ...              ...               ...
# 995      2024-12-28       2024-12-30             Zabka
# 996      2024-12-29       2024-12-31  Biuro Notarialne
# 997      2024-12-29       2024-12-30         Firma XYZ
# 998      2024-12-30       2024-12-30             Orlen
# 999      2024-12-31       2025-01-01            STS.pl
#
#                          tytuł                   nr_rachunku nazwa_banku  \
# 0               Płatność Orlen  PL47525525636630696177023059       mBank
# 1    Płatność Biuro Notarialne  PL72634487227183186158541068         ING
# 2          Płatność PokerStars  PL85502768236074445829791826   Santander
# ...

# %%
df['dane_kontrahenta'].value_counts()
# Out:
# dane_kontrahenta
# Firma XYZ                    59
# Auto Komis Katowice          59
# Vattenfall                   57
# ATM ING                      56
# Zabka                        55
# PokerStars                   53
# Allegro                      52
# Orlen                        51
# Biedronka                    51
# Biuro Nieruchomości ZEFIR    50
# Urząd Skarbowy               48
# Amazon                       48
# Santander Leasing            48
# Biuro Notarialne             46
# STS.pl                       46
# Lidl                         46
# PKO BP                       46
# Booking.com                  45
# PGNiG                        45
# MediaMarkt                   39
# Name: count, dtype: int64

# %%
red_flag_analyzer(df)

df
# Out:
#     data_transakcji data_księgowania  dane_kontrahenta  \
# 0        2019-01-01       2019-01-03             Orlen
# 1        2019-01-01       2019-01-02  Biuro Notarialne
# 2        2019-01-04       2019-01-04        PokerStars
# 3        2019-01-06       2019-01-07            Amazon
# 4        2019-01-10       2019-01-11    Urząd Skarbowy
# ..              ...              ...               ...
# 995      2024-12-28       2024-12-30             Zabka
# 996      2024-12-29       2024-12-31  Biuro Notarialne
# 997      2024-12-29       2024-12-30         Firma XYZ
# 998      2024-12-30       2024-12-30             Orlen
# 999      2024-12-31       2025-01-01            STS.pl
#
#                          tytuł                   nr_rachunku nazwa_banku  \
# 0               Płatność Orlen  PL47525525636630696177023059       mBank
# 1    Płatność Biuro Notarialne  PL72634487227183186158541068         ING
# 2          Płatność PokerStars  PL85502768236074445829791826   Santander
# ...

# %%
df['dane_kontrahenta'].value_counts()
# Out:
# dane_kontrahenta
# Firma XYZ                    59
# Auto Komis Katowice          59
# Vattenfall                   57
# ATM ING                      56
# Zabka                        55
# PokerStars                   53
# Allegro                      52
# Orlen                        51
# Biedronka                    51
# Biuro Nieruchomości ZEFIR    50
# Urząd Skarbowy               48
# Amazon                       48
# Santander Leasing            48
# Biuro Notarialne             46
# STS.pl                       46
# Lidl                         46
# PKO BP                       46
# Booking.com                  45
# PGNiG                        45
# MediaMarkt                   39
# Name: count, dtype: int64

# %%
df['red_flag'].value_counts()
# Out:
# red_flag
# 0    770
# 1    230
# Name: count, dtype: int64
